# %% [markdown]
# # 1. Import Library

# %%
! pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2. Web scrapping

# %%
# 헤더 정의 -> 웹 페이지에 접근할 수 있도록
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

#categories = []
titles1 = []


def title_scrapping(start_page, end_page):

    for page in range(start_page, end_page + 1):

      sub_titles = []

      print(f"👉{page} 페이지")

      url = f'https://www.snu.ac.kr/snunow/notice/genernal?page={page}'

      # request + html 소스 가져오기
      html = requests.get(url, headers = headers)

      # bs 객체 생성
      soup = BeautifulSoup(html.text, 'html.parser')
      # dt 태그 + class_ 인 것을 모두 찾기
      span_tags = soup.find_all('span', class_ = 'txt')

      # title
      for span_tag in span_tags:
        #span_tag = soup.find('span', class_ = 'txt')
        title = span_tag.text.strip()
        sub_titles.append(title)

      #print(f"sub_titles: {sub_titles}")
      #for idx in range((page - 5)*16, (page - 4)*16):
        #texts = titles[idx]
        #print(texts)

      for sub_title in sub_titles:
        print(sub_title)

      titles1.extend(sub_titles)

      print('\n')

# %%
# 일반 공지
title_scrapping(1, 78)
# Out:
# 👉1 페이지
# 2025년 서울대 대학원 전기 석사과정 신입학 SSBT 장학생 모집(~ 2024.08.19)
# [SSBT] 서울대 24년 후기 대학원 석사과정 신입생 대상 장학생 2차 모집(~2024.08.12.)
# 제78회 후기 학위수여식 개최 안내
# 2024년 가을학기 한국어 교사 양성과정 수강생 모집
# 2024년도 하반기 21세기 신규장각 자료구축사업(신진학자 연구 지원 프로그램) 신청 안내
# 2024학년도 2학기 관악학생생활관 입주대기자 신청 및 선발 안내
# 개인정보 처리방침 개정 고지(2024년 7월 2일자)
# 제34회「자랑스러운 서울대인」 후보 추천 공고
# 서울대학교 DYROS 로보틱스 부트캠프
# 2024학년도 제2학기 특별수강생 선발계획
#
#
# 👉2 페이지
# 제14회「서울대학교 사회봉사상」후보 추천 공고
# 서울대학교 언어교육원 2024년 여름학기 한국어 교사 양성과정 수강생 모집
# 제17회「서울대학교 발전공로상」후보 추천 공고
# 2024년도 8월 말 퇴직교원 정부포상 추천 후보자 공개검증
# 기초학문 등 지원·육성을 위한 4개년(2024~2027년) 계획 공표
# 2024년도 서울대학교 안전관리계획
# 2024학년도 1학기 등록금 납부 안내
# 2023년도 종합청렴도 평가 결과 공개
# 2024학년도 입학식 개최 안내
# 제78회 전기 학위수여식 개최 안내
#
#
# 👉3 페이지
# 2024년도 미래 신진연구자 지원 사업 안내
# 2024년 봄학기 한국어 교사 양성과정 수강생 모집
# 서울대학교 농업생명과학대학 농생명과학공동기기원 연구원 채용 공고
# 2024학년도 관악학생생활관 학부신입생 입주 신청 안내(학부신입생/편입생/재입학생)
# 서울대학교 해양시스템공학연구소 2024년 스마트야드 공학기술 특별강좌 개최
# 서울대학교 공과대학 사회봉사센터 '공헌'「동계 공드림 캠프」안내(신청기한 연장)
# 2024학년도 제1학기 특별수강생 선발계획
# 2023년 제2회, 제3회 서울대학교 AI빅데이터 캠프 개최
# ...

# %%
# 헤더 정의 -> 웹 페이지에 접근할 수 있도록
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

#categories = []
titles2 = []

def title_scrapping2(start_page, end_page):

    for page in range(start_page, end_page + 1):

      sub_titles = []

      print(f"👉{page} 페이지")

      url = f'https://www.snu.ac.kr/snunow/notice/job-openings?page={page}'

      # request + html 소스 가져오기
      html = requests.get(url, headers = headers)

      # bs 객체 생성
      soup = BeautifulSoup(html.text, 'html.parser')
      # dt 태그 + class_ 인 것을 모두 찾기
      span_tags = soup.find_all('span', class_ = 'txt')

      # title
      for span_tag in span_tags:
        #span_tag = soup.find('span', class_ = 'txt')
        title = span_tag.text.strip()
        sub_titles.append(title)

      #print(f"sub_titles: {sub_titles}")
      #for idx in range((page - 5)*16, (page - 4)*16):
        #texts = titles[idx]
        #print(texts)

      for sub_title in sub_titles:
        print(sub_title)

      titles2.extend(sub_titles)

      print('\n')

# %%
# 채용 공지

title_scrapping2(1, 22)
# Out:
# 👉1 페이지
# 서울대학교 교수초빙 공지
# 서울대학교 미래혁신연구원 글로벌 바이오 시흥캠퍼스 위탁사업 기간제 자체직원 공개경쟁 채용 공고
# 서울대학교 에너지시스템공학부 4단계 BK21 차세대 에너지 통합형 인력양성사업단 신진연구인력(박사후과정생) 채용 공고
# 서울대학교 빅데이터 혁신융합대학사업단 사무국 직원 채용
# 서울대학교 수의과대학 자체직원(기간제) 수의사 채용 공고
# 서울대학교 장애인 근로자 2차 채용 공고
# 칠보산학술림 자체직원(기간제) 채용 공고
# 서울대학교 원자력미래기술정책연구소 행정직원 채용 공고
# 서울대학교 농업생명과학대학 4단계 BK21 글로벌 스마트팜 혁신인재양성 교육연구단 박사후연수연구원 채용공고
# 서울대학교 언론정보학과 BK21 사업단 신진연구인력(박사후연구원) 채용 공고
#
#
# 👉2 페이지
# 서울대학교 공과대학 행정직원(휴직자 대체인력) 채용 공고
# 서울대학교 학생처(장애학생지원센터) 직원(무기계약직) 채용 공고
# 서울대학교 글로벌공학교육센터 미화직(무기계약) 채용공고
# 서울대학교 경력개발센터 전문위원 채용 공고
# 서울대학교 공과대학 전기·정보공학부 직원 기간제(대체인력) 채용 공고
# 서울대학교 수의과대학 자체직원(기간제) 수의사 채용 공고
# 서울대학교 법학전문대학원 직원[대체인력) 채용 공고
# 서울대학교 이차전지혁신연구소 기간제 행정직원(연구지원인력) 채용공고
# 서울대학교 시설관리직 신규채용 면접전형 합격자 공고
# 서울대학교 장애인 근로자 채용 최종합격자 공고
#
#
# 👉3 페이지
# 사범대학 AI융합교육학과 행정직원(계약직) 채용 공고
# 서울대학교 시흥캠퍼스본부 예비창업패키지 사업 전담 직원 채용 공고
# 서울대학교 시설관리직 (청소․경비) 공개채용 면접심사 합격자 공고
# 서울대학교 산학협력단 인력뱅크(8기) 연구비 관리 행정직원 채용 공고
# 서울대학교 행정대학원 행정직원 채용 공고
# 서울대학교 항공드론 혁신융합대학사업단 2024. 10. 1. 자 비전임교원 채용 공고
# ...

# %% [markdown]
# # 3. Export DataFrame

# %%
titles = titles1 + titles2
print(titles)
print(len(titles))
# Out:
# ['2025년 서울대 대학원 전기 석사과정 신입학 SSBT 장학생 모집(~ 2024.08.19)', '[SSBT] 서울대 24년 후기 대학원 석사과정 신입생 대상 장학생 2차 모집(~2024.08.12.)', '제78회 후기 학위수여식 개최 안내', '2024년 가을학기 한국어 교사 양성과정 수강생 모집', '2024년도 하반기 21세기 신규장각 자료구축사업(신진학자 연구 지원 프로그램) 신청 안내', '2024학년도 2학기 관악학생생활관 입주대기자 신청 및 선발 안내', '개인정보 처리방침 개정 고지(2024년 7월 2일자)', '제34회「자랑스러운 서울대인」 후보 추천 공고', '서울대학교\xa0DYROS\xa0로보틱스 부트캠프', '2024학년도 제2학기 특별수강생 선발계획', '제14회「서울대학교 사회봉사상」후보 추천 공고', '서울대학교 언어교육원 2024년 여름학기 한국어 교사 양성과정 수강생 모집', '제17회「서울대학교 발전공로상」후보 추천 공고', '2024년도 8월 말 퇴직교원 정부포상 추천 후보자 공개검증', '기초학문 등 지원·육성을 위한 4개년(2024~2027년) 계획 공표', '2024년도 서울대학교 안전관리계획', '2024학년도 1학기 등록금 납부 안내', '2023년도 종합청렴도 평가 결과 공개', '2024학년도 입학식 개최 안내', '제78회 전기 학위수여식 개최 안내', '2024년도 미래 신진연구자 지원 사업 안내', '2024년 봄학기 한국어 교사 양성과정 수강생 모집', '서울대학교 농업생명과학대학 농생명과학공동기기원 연구원 채용 공고', '2024학년도 관악학생생활관 학부신입생 입주 신청 안내(학부신입생/편입생/재입학생)', '서울대학교 해양시스템공학연구소 2024년 스마트야드 공학기술 특별강좌 개최', "서울대학교 공과대학 사회봉사센터 '공헌'「동계 공드림 캠프」안내(신청기한 연장)", '2024학년도 제1학기 특별수강생 선발계획', '2023년 제2회, 제3회 서울대학교 AI빅데이터 캠프 개최', '2024학
# ...

# %%
test_notification = pd.DataFrame({'title': titles})

# %%
test_notification
# Out:
#                                                  title
# 0    2025년 서울대 대학원 전기 석사과정 신입학 SSBT 장학생 모집(~ 2024.0...
# 1    [SSBT] 서울대 24년 후기 대학원 석사과정 신입생 대상 장학생 2차 모집(~2...
# 2                                  제78회 후기 학위수여식 개최 안내
# 3                        2024년 가을학기 한국어 교사 양성과정 수강생 모집
# 4    2024년도 하반기 21세기 신규장각 자료구축사업(신진학자 연구 지원 프로그램) 신...
# ..                                                 ...
# 989                  서울대학교 산학협력공학인재지원센터 지원사업 담당자 채용 공고
# 990                      서울대학교 사회과학연구원 자체직원(계약직) 채용 공고
# 991                  서울대학교 에너지신산업 혁신융합대학사업단 행정직원 채용 공고
# 992                              아시아연구소 직원(행정실장) 채용 공고
# 993                                 서울대학교박물관 연구원 채용 공고
#
# [994 rows x 1 columns]

# %%
test_notification.to_csv('/content/drive/MyDrive/test_notification.csv', index=False, encoding='utf-8-sig')
